# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import cv2

# %%
img = cv2.imread("cat.jpg")
plt.imshow(img)

# %%
img_array = np.array(img)
img_array.shape
# RGB
(1280, 720, 3)
# Assuming you have an image 'img' with shape (height, width,channels)
print("Original image shape:", img.shape)
# Reshape the image into a 2D array
img_reshaped = img.reshape(-1, img.shape[-1])
print("Reshaped image shape:", img_reshaped.shape)
# Original image shape: (243, 207, 3)
# Reshaped image shape: (50301, 3)
# Apply PCA
pca = PCA(n_components=2) # You can choose the desired number of
components
img_pca = pca.fit_transform(img_reshaped)
# Print the shape of the PCA-transformed image
print("PCA-transformed image shape:", img_pca.shape)
# Out:
# Original image shape: (1282, 1920, 3)
# Reshaped image shape: (2461440, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-edff40b7e82c> in <module>
#      11 # Reshaped image shape: (50301, 3)
#      12 # Apply PCA
# ---> 13 pca = PCA(n_components=2) # You can choose the desired number of
#      14 components
#      15 img_pca = pca.fit_transform(img_reshaped)
#
# NameError: name 'PCA' is not defined
